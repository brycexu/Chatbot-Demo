# %% [markdown]
# # Facutal Information Extraction QA from JSON file

# %% [markdown]
# ## New WORKFLOW
# 1. Extract Company Name: NER Model
# 2. Get ticker name
# 3. Call Yahoo API for ticker infomation
# 4. Embedding query and key
# 5. pick the key with highest cosime similarity
# 6. Answer would be the value corresponding to the key

# %%
# !pip install yfinance
# !pip install sentence_transformers
# !pip install transformers

# %%
from sentence_transformers import SentenceTransformer, util
from transformers import pipeline
import re
import yfinance as yf
import requests

# %%
embed_model = SentenceTransformer('distilbert-base-nli-stsb-mean-tokens')
ner_model = "Jean-Baptiste/roberta-large-ner-english" # "huggingface-course/bert-finetuned-ner"
token_classifier = pipeline(
    "token-classification", model=ner_model, aggregation_strategy="simple"
)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/849 [00:00<?, ?B/s]
# Downloading (…)"pytorch_model.bin";:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/255 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]

# %%
def get_ticker_name(company_name):
    yfinance = "https://query2.finance.yahoo.com/v1/finance/search"
    user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36'
    params = {"q": company_name, "quotes_count": 1, "country": "United States"}

    res = requests.get(url=yfinance, params=params, headers={'User-Agent': user_agent})
    data = res.json()

    company_code = data['quotes'][0]['symbol']
    return company_code

# %%
def get_ticker(query):
    tokens = token_classifier(query)
    company_name = None
    for token in tokens:
        if token['entity_group'] == 'ORG':
            company_name = token['word']
    if not company_name:
        print(f"no company name found in the query: {query}")
        return (None, None)
    tikername = get_ticker_name(company_name)
    ticker = yf.Ticker(tikername)
    return ticker, company_name

# %%
def get_key(query, keys):
  max_key, max_cos = '', 0
  for key in keys:
    embedding_1= embed_model.encode(query, convert_to_tensor=True)
    if key[-2:] == "PE":
        new_key = f'{key[:-2]} {key[-2:]}'
    else:
        new_key=re.sub( r"([A-Z])", r" \1", key).split()
        new_key=" ".join(new_key)
        new_key=new_key.lower()
    embedding_2 = embed_model.encode('the ' + new_key + 'of Tesla', convert_to_tensor=True)
    score = util.pytorch_cos_sim(embedding_1, embedding_2)
    if score[0][0] > max_cos:
      max_key, max_cos = key, score
  return max_key, max_cos

# %%
def FactualQA(query):
    ticker, company_name = get_ticker(query)
    if ticker is None:
      return "Unable to detect company name"
    info_dict = dict(ticker.info)
    key, score = get_key(query, info_dict.keys())
    answer = info_dict[key] if info_dict[key] is not None else "unavailable"
    return f"Answer: '{answer}', score: {score.numpy()}"

# %%
FactualQA('What is the full time employees of Tesla?')
# Out:
# WARNING: No decryption keys could be extracted from JS file. Falling back to backup decrypt methods.
# "Answer: '127855', score: [[0.8278109]]"

# %% [markdown]
# ## EVALUATION

# %%
company_list = ['Tesla']
def create_qa_pairs():
    qa_pairs = []
    for company in company_list:
        tikername = get_ticker_name(company)
        ticker_info = dict(yf.Ticker(tikername).info)
        for key,val in ticker_info.items():
            if key == 'companyOfficers':
                question = f"How many officers are in {company}?"
                answer = "unavailable" if val is None else str(val)
                qa_pairs.append((question, answer))
                continue
            if key[-2:] == "PE":
              key = f'{key[:-2]} {key[-2:]}'
            else:
              key=re.sub( r"([A-Z])", r" \1", key).split()
              key=" ".join(key)
              key=key.lower()
            question = f"What is the {key} of {company}?"
            answer = "unavailable" if val is None else str(val)
            qa_pairs.append((question, answer))
    return qa_pairs

# %%
dataset = create_qa_pairs()
dataset
# Out:
# WARNING: No decryption keys could be extracted from JS file. Falling back to backup decrypt methods.
# [('What is the zip of Tesla?', '78725'),
#  ('What is the sector of Tesla?', 'Consumer Cyclical'),
#  ('What is the full time employees of Tesla?', '127855'),
#  ('What is the long business summary of Tesla?',
#   'Tesla, Inc. designs, develops, manufactures, leases, and sells electric vehicles, and energy generation and storage systems in the United States, China, and internationally. It operates in two segments, Automotive, and Energy Generation and Storage. The Automotive segment offers electric vehicles, as well as sells automotive regulatory credits; and non-warranty after-sales vehicle, used vehicles, retail merchandise, and vehicle insurance services. This segment also provides sedans and sport utility vehicles through direct and used vehicle sales, a network of Tesla Superchargers, and in-app upgrades; purchase financing and leasing services; services for electric vehicles through its company-owned service locations and Tesla mobile service technicians; and vehicle limited warranties and extended service plans. The Energy Generation and Storage segment engages in the design, manufacture, installation, sale, and leasing of solar energy generation and energy storage products, and related services to residential, commercial, and industrial customers and utilities through its website, stores, and galleries, as well as through a network of channel partners; and provision of service and repairs to its energy product customers, including under warranty, as well as various financing options to its solar customers. The company was formerly known as Tesla Motors, Inc. and changed its name to Tesla, Inc. in February 2017. Tesla, Inc. was incorporated in 2003 and is headquartered in Austin, Texas.'),
#  ('What is the city of Tesla?', 'Austin'),
#  ('What is the phone of Tesla?', '512 516 8177'),
#  ('What is the state of Tesla?', 'TX'),
#  ('What is the country of Tesla?', 'United States'),
#  ('How many officers are in Tesla?', '[]'),
#  ('What is the website of Tesla?', 'https://www.tesla.com'),
#  ('What is the max age of Tesla?', '1'),
#  ('What is the address1 of Tesla?', '1 Tesla Road'),
#  ('What is the industry of Tesla?', 'Auto Manufacturers'),
#  ('What is the ebitda margins of Tesla?', '0.21406999'),
#  ('What is the profit margins of Tesla?', '0.15413'),
#  ('What is the gross margins of Tesla?', '0.25597998'),
#  ('What is the operating cashflow of Tesla?', '14723999744'),
#  ('What is the revenue growth of Tesla?', '0.372'),
#  ('What is the operating margins of Tesla?', '0.16808'),
#  ('What is the ebitda of Tesla?', '17439000576'),
#  ('What is the target low price of Tesla?', '24.33'),
#  ('What is the recommendation key of Tesla?', 'buy'),
#  ('What is the gross profits of Tesla?', '20853000000'),
#  ('What is the free cashflow of Tesla?', '4208124928'),
#  ('What is the target median price of Tesla?', '196'),
#  ('What is the earnings growth of Tesla?', '0.569'),
#  ('What is the current ratio of Tesla?', '1.532'),
#  ('What is the return on assets of Tesla?', '0.11847'),
#  ('What is the number of analyst opinions of Tesla?', '35'),
#  ('What is the target mean price of Tesla?', '186.61'),
#  ('What is the debt to equity of Tesla?', '12.523'),
#  ('What is the return on equity of Tesla?', '0.32490003'),
#  ('What is the target high price of Tesla?', '300'),
#  ('What is the total cash of Tesla?', '22185000960'),
#  ('What is the total debt of Tesla?', '5747999744'),
#  ('What is the total revenue of Tesla?', '81462001664'),
#  ('What is the total cash per share of Tesla?', '7.011'),
#  ('What is the financial currency of Tesla?', 'USD'),
#  ('What is the revenue per share of Tesla?', '26.026'),
#  ('What is the quick ratio of Tesla?', '0.947'),
#  ('What is the recommendation mean of Tesla?', '2.3'),
#  ('What is the short name of Tesla?', 'Tesla, Inc.'),
#  ('What is the long name of Tesla?', 'Tesla, Inc.'),
#  ('What is the is esg populated of Tesla?', 'False'),
#  ('What is the gmt off set milliseconds of Tesla?', '-18000000'),
#  ('What is the message board id of Tesla?', 'finmb_27444752'),
#  ('What is the market of Tesla?', 'us_market'),
#  ('What is the annual holdings turnover of Tesla?', 'unavailable'),
#  ('What is the enterprise to revenue of Tesla?', '7.46'),
#  ('What is the beta3 year of Tesla?', 'unavailable'),
#  ('What is the enterprise to ebitda of Tesla?', '34.849'),
#  ('What is the morning star risk rating of Tesla?', 'unavailable'),
#  ('What is the forward eps of Tesla?', '5.52'),
#  ('What is the revenue quarterly growth of Tesla?', 'unavailable'),
#  ('What is the shares outstanding of Tesla?', '3164100096'),
#  ('What is the fund inception date of Tesla?', 'unavailable'),
#  ('What is the annual report expense ratio of Tesla?', 'unavailable'),
#  ('What is the total assets of Tesla?', 'unavailable'),
#  ('What is the book value of Tesla?', '14.129'),
#  ('What is the shares short of Tesla?', '90314882'),
#  ('What is the shares percent shares out of Tesla?', '0.028499998'),
#  ('What is the fund family of Tesla?', 'unavailable'),
#  ('What is the last fiscal year end of Tesla?', '1672444800'),
#  ('What is the held percent institutions of Tesla?', '0.45246'),
#  ('What is the net income to common of Tesla?', '12583000064'),
#  ('What is the trailing eps of Tesla?', '3.44'),
#  ('What is the last dividend value of Tesla?', 'unavailable'),
#  ('What is the sand p52 week change of Tesla?', '-0.075727224'),
#  ('What is the price to book of Tesla?', '15.16314'),
#  ('What is the held percent insiders of Tesla?', '0.16292'),
#  ('What is the next fiscal year end of Tesla?', '1703980800'),
#  ('What is the yield of Tesla?', 'unavailable'),
#  ('What is the most recent quarter of Tesla?', '1672444800'),
#  ('What is the short ratio of Tesla?', '0.46'),
#  ('What is the shares short previous month date of Tesla?', '1672358400'),
#  ('What is the float shares of Tesla?', '2691449040'),
#  ('What is the beta of Tesla?', '2.108089'),
#  ('What is the enterprise value of Tesla?', '607737151488'),
#  ('What is the price hint of Tesla?', '2'),
#  ('What is the three year average return of Tesla?', 'unavailable'),
#  ('What is the last split date of Tesla?', '1661385600'),
#  ('What is the last split factor of Tesla?', '3:1'),
#  ('What is the legal type of Tesla?', 'unavailable'),
#  ('What is the last dividend date of Tesla?', 'unavailable'),
#  ('What is the morning star overall rating of Tesla?', 'unavailable'),
#  ('What is the earnings quarterly growth of Tesla?', '0.589'),
#  ('What is the price to sales trailing12 months of Tesla?', '8.321386'),
#  ('What is the date short interest of Tesla?', '1675123200'),
#  ('What is the peg ratio of Tesla?', '2.08'),
#  ('What is the ytd return of Tesla?', 'unavailable'),
#  ('What is the forward PE of Tesla?', '38.811596'),
#  ('What is the last cap gain of Tesla?', 'unavailable'),
#  ('What is the short percent of float of Tesla?', '0.0348'),
#  ('What is the shares short prior month of Tesla?', '80186849'),
#  ('What is the implied shares outstanding of Tesla?', '0'),
#  ('What is the category of Tesla?', 'unavailable'),
#  ('What is the five year average return of Tesla?', 'unavailable'),
#  ('What is the trailing annual dividend yield of Tesla?', '0'),
#  ('What is the payout ratio of Tesla?', '0'),
#  ('What is the nav price of Tesla?', 'unavailable'),
#  ('What is the trailing annual dividend rate of Tesla?', '0'),
#  ('What is the to currency of Tesla?', 'unavailable'),
#  ('What is the expire date of Tesla?', 'unavailable'),
#  ('What is the algorithm of Tesla?', 'unavailable'),
#  ('What is the dividend rate of Tesla?', 'unavailable'),
#  ('What is the ex dividend date of Tesla?', 'unavailable'),
#  ('What is the circulating supply of Tesla?', 'unavailable'),
#  ('What is the start date of Tesla?', 'unavailable'),
#  ('What is the trailing PE of Tesla?', '62.27907'),
#  ('What is the last market of Tesla?', 'unavailable'),
#  ('What is the max supply of Tesla?', 'unavailable'),
#  ('What is the open interest of Tesla?', 'unavailable'),
#  ('What is the volume all currencies of Tesla?', 'unavailable'),
#  ('What is the strike price of Tesla?', 'unavailable'),
#  ('What is the ask of Tesla?', '214.17'),
#  ('What is the ask size of Tesla?', '1000'),
#  ('What is the from currency of Tesla?', 'unavailable'),
#  ('What is the five year avg dividend yield of Tesla?', 'unavailable'),
#  ('What is the bid of Tesla?', '214.77'),
#  ('What is the tradeable of Tesla?', 'False'),
#  ('What is the dividend yield of Tesla?', 'unavailable'),
#  ('What is the bid size of Tesla?', '800'),
#  ('What is the coin market cap link of Tesla?', 'unavailable'),
#  ('What is the pre market price of Tesla?', '211.775'),
#  ('What is the logo_url of Tesla?', 'https://logo.clearbit.com/tesla.com'),
#  ('What is the trailing peg ratio of Tesla?', '1.7019')]

# %%
acc = 0
errors = []
for question, anwser in dataset:
  predict = FactualQA(question)
  if anwser in predict:
      acc += 1
  else:
    errors.append((question, anwser, predict))
num = len(dataset)

# %%
print(acc/num)
print(errors)
# Out:
# 0.9047619047619048
# [('What is the zip of Tesla?', '78725', 'Unable to detect company name'), ('What is the city of Tesla?', 'Austin', 'Unable to detect company name'), ('What is the gross profits of Tesla?', '20853000000', "Answer: '0.15413', score: [[0.83484954]]"), ('What is the target high price of Tesla?', '300', "Answer: '186.61', score: [[0.86713934]]"), ('What is the total cash of Tesla?', '22185000960', "Answer: '7.011', score: [[0.87282354]]"), ('What is the long name of Tesla?', 'Tesla, Inc.', 'Unable to detect company name'), ('What is the shares outstanding of Tesla?', '3164100096', "Answer: '0.028499998', score: [[0.81111366]]"), ('What is the book value of Tesla?', '14.129', "Answer: '15.16314', score: [[0.8181623]]"), ('What is the shares short prior month of Tesla?', '80186849', "Answer: '1672358400', score: [[0.8579195]]"), ('What is the algorithm of Tesla?', 'unavailable', 'Unable to detect company name'), ('What is the ask of Tesla?', '214.17', "Answer: '215.93', score: [[0.779809]]"), ('What is the bid of Tesla?', '214.77', "Answer: '215.91', score: [[0.8743908]]")]

# %% [markdown]
# ## OLD WORKFLOW
# 1. Extract Company Name: NER Model
# 2. Get ticker name
# 3. Call Yahoo API for ticker infomation
# 4. Create context: Verbolize Json File
# 5. Feed query and context into QA Model

# %%
# !pip install yfinance
# !pip install transformers

# %%
ner_model = "Jean-Baptiste/roberta-large-ner-english" # "huggingface-course/bert-finetuned-ner"
token_classifier = pipeline(
    "token-classification", model=ner_model, aggregation_strategy="simple"
)
qa_model = "distilbert-base-cased-distilled-squad"
question_answerer = pipeline("question-answering", model=qa_model)

# %%
def get_ticker_name(company_name):
    yfinance = "https://query2.finance.yahoo.com/v1/finance/search"
    user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36'
    params = {"q": company_name, "quotes_count": 1, "country": "United States"}

    res = requests.get(url=yfinance, params=params, headers={'User-Agent': user_agent})
    data = res.json()

    company_code = data['quotes'][0]['symbol']
    return company_code

# %%
def get_ticker(query):
    tokens = token_classifier(query)
    company_name = None
    for token in tokens:
        if token['entity_group'] == 'ORG':
            company_name = token['word']
    if not company_name:
        print(f"no company name found in the query: {query}")
        return (None, None)
    tikername = get_ticker_name(company_name)
    ticker = yf.Ticker(tikername)
    return ticker, company_name

# %%
def verbalize(company, info_dict):
  res = []
  for key,val in info_dict.items():
    if key == 'longBusinessSummary':
      res.append(val)
    else:
      if val is None: 
        val = "unavailable"
      elif key[-2:] == "PE":
        key = f'{key[:-2]} {key[-2:]}'
      elif key == 'companyOfficers':
        res.append(f"The officers of {company} are {', '.join(val)}.")
      else:
        key=re.sub( r"([A-Z])", r" \1", key).split()
        key=" ".join(key)
        key=key.lower()
      res.append(f"The {key} of {company} is {str(val)}.")
  
  res.append(f"The {company} is located in {info_dict['address1']}, {info_dict['city']}, {info_dict['state']}, {info_dict['country']} {info_dict['zip']}.")
  return " ".join(res)

# %%
def QA(query):
    ticker, company_name = get_ticker(query)
    if ticker is None:
      return "Unable to detect company name"
    context = verbalize(company_name, dict(ticker.info))
    result = question_answerer(question=query, context=context)
    return f"Answer: '{result['answer']}', score: {round(result['score'], 4)}, start: {result['start']}, end: {result['end']}"
